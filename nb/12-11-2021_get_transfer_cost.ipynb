# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from loguru import logger

import pickle
import requests
import json
import re
from pathlib import Path

data_dir = Path(globals()['_dh'][0]).parent / 'data'
figure_dir = data_dir / 'figures' / 'get_transfer_costs'
figure_dir.mkdir(exist_ok=True)

plt.style.use('seaborn-bright')
plt.set_cmap('plasma')

data_link = "https://b0.p.awsstatic.com/pricing/2.0/meteredUnitMaps/datatransfer/USD/current/datatransfer.json"
data = requests.get(data_link).json()

# %%
data['regions'].keys()
# Out:
# dict_keys(['AWS GovCloud (US)', 'AWS GovCloud (US-East)', 'Africa (Cape Town)', 'Asia Pacific (Hong Kong)', 'Asia Pacific (KDDI) - Osaka', 'Asia Pacific (KDDI) - Tokyo', 'Asia Pacific (Mumbai)', 'Asia Pacific (Osaka)', 'Asia Pacific (SKT) - Daejeon', 'Asia Pacific (Seoul)', 'Asia Pacific (Singapore)', 'Asia Pacific (Sydney)', 'Asia Pacific (Tokyo)', 'Canada (Central)', 'EU (Frankfurt)', 'EU (Ireland)', 'EU (London)', 'EU (Milan)', 'EU (Paris)', 'EU (Stockholm)', 'EU (Vodafone) - Berlin', 'EU (Vodafone) - Dortmund', 'EU (Vodafone) - London', 'EU (Vodafone) - Munich', 'Middle East (Bahrain)', 'South America (Sao Paulo)', 'US East (Boston)', 'US East (Chicago)', 'US East (Dallas)', 'US East (Houston)', 'US East (Kansas City 2)', 'US East (Miami)', 'US East (Minneapolis)', 'US East (N. Virginia)', 'US East (New York City)', 'US East (Ohio)', 'US East (Philadelphia)', 'US East (Verizon) - Atlanta', 'US East (Verizon) - Boston', 'US East (Verizon) - Chicago', 'US East (Verizon) - Dallas', 'US East (Verizon) - Houston', 'US East (Verizon) - Miami', 'US East (Verizon) - New York', 'US East (Verizon) - Washington DC', 'US West (Denver)', 'US West (Las Vegas)', 'US West (Los Angeles)', 'US West (N. California)', 'US West (Oregon)', 'US West (Portland)', 'US West (Verizon) - Denver', 'US West (Verizon) - Las Vegas', 'US West (Verizon) - Phoenix', 'US West (Verizon) - San Francisco Bay Area', 'US West (Verizon) - Seattle'])

# %%
# get region names
region_name_map = {'Africa (Cape Town)': 'af-south-1', 'Asia Pacific (Hong Kong)': 'ap-east-1', 'Asia Pacific (Mumbai)': 'ap-south-1', 'Asia Pacific (Osaka)': 'ap-northeast-3', 'Asia Pacific (Seoul)': 'ap-northeast-2', 'Asia Pacific (Singapore)': 'ap-southeast-1', 'Asia Pacific (Sydney)': 'ap-southeast-2', 'Asia Pacific (Tokyo)': 'ap-northeast-1', 'AWS GovCloud (US-East)': 'us-gov-east-1', 'AWS GovCloud (US-West)': 'us-gov-west-1', 'Canada (Central)': 'ca-central-1', 'Europe (Frankfurt)': 'eu-central-1', 'Europe (Ireland)': 'eu-west-1', 'Europe (London)': 'eu-west-2', 'Europe (Milan)': 'eu-south-1', 'Europe (Paris)': 'eu-west-3', 'Europe (Stockholm)': 'eu-north-1', 'Middle East (Bahrain)': 'me-south-1', 'South America (São Paulo)': 'sa-east-1', 'US East (N. Virginia)': 'us-east-1', 'US East (Ohio)': 'us-east-2', 'US West (N. California)': 'us-west-1', 'US West (Oregon)': 'us-west-2'}
new_region_name_map_items = {}
for region_english, region_code in region_name_map.items():
    if region_english.startswith('Europe'):
        new_region_name_map_items[region_english.replace('Europe', 'EU')] = region_code
        new_name = region_english.replace('Europe', 'EU').replace('(', '').replace(')', '')
        new_region_name_map_items[new_name] = region_code
    if '(' in region_english:
        new_name = region_english.replace('(', '').replace(')', '')
        new_region_name_map_items[new_name] = region_code
region_name_map.update(new_region_name_map_items)
region_name_map['South America Sao Paulo'] = 'sa-east-1'
region_name_map['South America (Sao Paulo)'] = 'sa-east-1'
region_name_map['South America (São Paulo)'] = 'sa-east-1'
region_name_map['South America São Paulo'] = 'sa-east-1'
region_name_map['US East N. Virginia'] = 'us-east-1'
region_name_map['US East N Virginia'] = 'us-east-1'
region_name_map['US West N. California'] = 'us-west-1'
region_name_map['US West N California'] = 'us-west-1'

# parse json
cost_per_gb = []
unparsed_regions = []
for src_region, region_data in data['regions'].items():
    src = region_name_map.get(src_region)
    if src is None:
        logger.info(f"Missing region {src} ({src_region})")
        unparsed_regions.append(src_region)
    else:
        for dst_region, dst_region_data in region_data.items():
            cost = float(dst_region_data['price'])
            if dst_region.startswith('DataTransfer External Inbound'):
                assert cost == 0.
            elif dst_region.startswith('DataTransfer External Outbound'):
                regex = re.compile(r'DataTransfer External Outbound (?P<volume>.*)')
                match = regex.search(dst_region)
                if match:
                    if match.group('volume') == 'Next 10 TB':
                        cost_per_gb.append(dict(src=src, dst='internet', cost=cost))
                else:
                    logger.error(f'Could not parse {dst_region}')
            elif dst_region.startswith('DataTransfer InterRegion Outbound to'):
                regex = re.compile(r'DataTransfer InterRegion Outbound to (?P<dst_region>.*)')
                match = regex.search(dst_region)
                if match:
                    dst = region_name_map.get(match.group('dst_region'))
                    if dst is None:
                        unparsed_regions.append(match.group('dst_region'))
                    else:
                        cost_per_gb.append(dict(src=src, dst=dst, cost=cost))
                else:
                    logger.error(f'Could not parse {dst_region}')
            elif dst_region.startswith('Cloudfrontless') or dst_region.startswith('DirectoryService') or dst_region.startswith('Backup') or dst_region.startswith('RDS') or dst_region.startswith('FSX'):
                pass
            else:
                unparsed_regions.append(dst_region)
df = pd.DataFrame(cost_per_gb)
df.to_csv(data_dir / '..' / 'profiles' / 'aws_transfer_costs.csv', index=False)
# Out:
# 2021-12-12 01:39:26.709 | INFO     | __main__:<module>:28 - Missing region None (AWS GovCloud (US))
# 2021-12-12 01:39:26.711 | INFO     | __main__:<module>:28 - Missing region None (Asia Pacific (KDDI) - Osaka)
# 2021-12-12 01:39:26.712 | INFO     | __main__:<module>:28 - Missing region None (Asia Pacific (KDDI) - Tokyo)
# 2021-12-12 01:39:26.714 | INFO     | __main__:<module>:28 - Missing region None (Asia Pacific (SKT) - Daejeon)
# 2021-12-12 01:39:26.718 | INFO     | __main__:<module>:28 - Missing region None (EU (Vodafone) - Berlin)
# 2021-12-12 01:39:26.719 | INFO     | __main__:<module>:28 - Missing region None (EU (Vodafone) - Dortmund)
# 2021-12-12 01:39:26.721 | INFO     | __main__:<module>:28 - Missing region None (EU (Vodafone) - London)
# 2021-12-12 01:39:26.726 | INFO     | __main__:<module>:28 - Missing region None (EU (Vodafone) - Munich)
# 2021-12-12 01:39:26.729 | INFO     | __main__:<module>:28 - Missing region None (US East (Boston))
# 2021-12-12 01:39:26.731 | INFO     | __main__:<module>:28 - Missing region None (US East (Chicago))
# 2021-12-12 01:39:26.731 | INFO     | __main__:<module>:28 - Missing region None (US East (Dallas))
# 2021-12-12 01:39:26.732 | INFO     | __main__:<module>:28 - Missing region None (US East (Houston))
# 2021-12-12 01:39:26.733 | INFO     | __main__:<module>:28 - Missing region None (US East (Kansas City 2))
# 2021-12-12 01:39:26.734 | INFO     | __main__:<module>:28 - Missing region None (US East (Miami))
# 2021-12-12 01:39:26.735 | INFO     | __main__:<module>:28 - Missing region None (US East (Minneapolis))
# 2021-12-12 01:39:26.741 | INFO     | __main__:<module>:28 - Missing region None (US East (New York City))
# 2021-12-12 01:39:26.743 | INFO     | __main__:<module>:28 - Missing region None (US East (Philadelphia))
# 2021-12-12 01:39:26.744 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Atlanta)
# 2021-12-12 01:39:26.745 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Boston)
# 2021-12-12 01:39:26.746 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Chicago)
# 2021-12-12 01:39:26.747 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Dallas)
# 2021-12-12 01:39:26.748 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Houston)
# 2021-12-12 01:39:26.749 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Miami)
# 2021-12-12 01:39:26.751 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - New York)
# 2021-12-12 01:39:26.752 | INFO     | __main__:<module>:28 - Missing region None (US East (Verizon) - Washington DC)
# 2021-12-12 01:39:26.753 | INFO     | __main__:<module>:28 - Missing region None (US West (Denver))
# 2021-12-12 01:39:26.754 | INFO     | __main__:<module>:28 - Missing region None (US West (Las Vegas))
# 2021-12-12 01:39:26.755 | INFO     | __main__:<module>:28 - Missing region None (US West (Los Angeles))
# 2021-12-12 01:39:26.756 | INFO     | __main__:<module>:28 - Missing region None (US West (Portland))
# 2021-12-12 01:39:26.757 | INFO     | __main__:<module>:28 - Missing region None (US West (Verizon) - Denver)
# 2021-12-12 01:39:26.758 | INFO     | __main__:<module>:28 - Missing region None (US West (Verizon) - Las Vegas)
# 2021-12-12 01:39:26.759 | INFO     | __main__:<module>:28 - Missing region None (US West (Verizon) - Phoenix)
# 2021-12-12 01:39:26.760 | INFO     | __main__:<module>:28 - Missing region None (US West (Verizon) - San Francisco Bay Area)
# 2021-12-12 01:39:26.761 | INFO     | __main__:<module>:28 - Missing region None (US West (Verizon) - Seattle)

# %%
df_gcp_regions = pd.read_csv(data_dir / '..' / 'profiles' / 'gcp_regions.csv')
gcp_region_map = dict(zip(df_gcp_regions['GCP name'], df_gcp_regions['GCP code']))

df_gcp = pd.read_csv(data_dir / '..' / 'profiles' / 'gcp_raw_pricing_api.csv')
df_gcp = df_gcp[df_gcp['Service description'] == 'Compute Engine']
df_gcp = df_gcp[df_gcp['Product taxonomy'].str.startswith('GCP > Network > Egress')]
df_gcp = df_gcp[df_gcp['Product taxonomy'] != 'GCP > Network > Egress > GCE > Premium > PD']
df_gcp['Egress tier'] = df_gcp['Product taxonomy'].str.split('>').str[-1]
df_gcp[['SKU description', 'Egress tier', 'List price ($)', 'Tiered usage start', 'Unit description', 'Per unit quantity']]

out_rows = []
bw_tuples = []
mismatches = []
for row in df_gcp.iterrows():
    row = row[1]
    if 'Internet' in row['SKU description'] and 'from' in row['SKU description'] and 'to' in row['SKU description']:
        regex = re.compile(r'Network Internet(?P<tier>.*) Egress from (?P<region>.*) to (?P<dst_region>.*)')
        match = regex.search(row['SKU description'])
        if match:
            src = match.group('region')
            dst = match.group('dst_region')
            bw_tuples.append(dict(src=src, dst=dst, cost=row['List price ($)'], unit=row['Unit description'], quantity=row['Per unit quantity'], tier=row['Egress tier'], tier_start=row['Tiered usage start']))
        else:
            logger.error(f'Could not parse {row["SKU description"]}')
    elif 'Internet' in row['SKU description'] and 'from' in row['SKU description'] and 'to' not in row['SKU description']:
        regex = re.compile(r'Network Internet(?P<tier>.*) Egress from (?P<region>.*)')
        match = regex.search(row['SKU description'])
        if match:
            src = match.group('region')
            dst = 'internet'
            bw_tuples.append(dict(src=src, dst=dst, cost=row['List price ($)'], unit=row['Unit description'], quantity=row['Per unit quantity'], tier=row['Egress tier'], tier_start=row['Tiered usage start']))
        else:
            logger.error(f'Could not parse {row["SKU description"]}')
    elif 'from' in row['SKU description'] and 'to' in row['SKU description']:
        regex = re.compile(r'.*from (?P<from>.*) to (?P<to>.*)')
        match = regex.search(row['SKU description'])
        if match:
            src = match.group('from')
            dst = match.group('to')
            bw_tuples.append(dict(src=src, dst=dst, cost=row['List price ($)'], unit=row['Unit description'], quantity=row['Per unit quantity'], tier=row['Egress tier'], tier_start=row['Tiered usage start']))
        else:
            logger.error(f'Could not parse {row["SKU description"]}')
    else:
        out_rows.append(row)
df_gcp_bw = pd.DataFrame(bw_tuples)
df_gcp_out = pd.DataFrame(out_rows)
# df_gcp_bw.to_csv(data_dir / '..' / 'profiles' / 'gcp_bw_costs.csv', index=False)
# Out:
# 2021-12-11 20:37:11.331 | ERROR    | __main__:<module>:24 - Could not parse Network Internet Standard Tier Egress from Toronto
# 2021-12-11 20:37:11.332 | ERROR    | __main__:<module>:24 - Could not parse Network Internet Standard Tier Egress from Toronto
# 2021-12-11 20:37:11.333 | ERROR    | __main__:<module>:24 - Could not parse Network Internet Standard Tier Egress from Toronto

# %%
# match src, dst to region names
unmatched_pairs = []
out_rows = []
print(gcp_region_map.keys())
for row in df_gcp_bw.iterrows():
    row = row[1]
    src = row['src']
    dst = row['dst']
    if src in gcp_region_map:
        row['src'] = gcp_region_map[src]
    else:
        unmatched_pairs.append((src, dst))
    if dst in gcp_region_map:
        row['dst'] = gcp_region_map[dst]
    elif dst == 'internet':
        row['dst'] = 'internet'
    else:
        unmatched_pairs.append((src, dst))
    out_rows.append(row)
df_gcp_bw = pd.DataFrame(out_rows)
df_gcp_bw = df_gcp_bw[df_gcp_bw['tier_start'] == 0.]
df_gcp_bw.to_csv(data_dir / '..' / 'profiles' / 'gcp_bw_costs.csv', index=False)
# Out:
# dict_keys(['Belgium', 'Delhi', 'Finland', 'Frankfurt', 'Hong Kong', 'Iowa', 'Jakarta', 'Las Vegas', 'London', 'Los Angeles', 'Melbourne', 'Montreal', 'Mumbai', 'Netherlands', 'Oregon', 'Osaka', 'Salt Lake City', 'Sao Paulo', 'Seoul', 'Singapore', 'South Carolina', 'Sydney', 'Taiwan', 'Tokyo', 'Toronto', 'Virginia', 'Warsaw', 'Zurich'])

# %%
set(unmatched_pairs)
# Out:
# {('APAC', 'APAC'),
#  ('APAC', 'Africa'),
#  ('APAC', 'Americas'),
#  ('APAC', 'Australia'),
#  ('APAC', 'Central America'),
#  ('APAC', 'China'),
#  ('APAC', 'Delhi'),
#  ('APAC', 'EMEA'),
#  ('APAC', 'Eastern Europe'),
#  ('APAC', 'Finland'),
#  ('APAC', 'Frankfurt'),
#  ('APAC', 'Hong Kong'),
#  ('APAC', 'India'),
#  ('APAC', 'Jakarta'),
#  ('APAC', 'Japan'),
#  ('APAC', 'Las Vegas'),
#  ('APAC', 'London'),
#  ('APAC', 'Los Angeles'),
#  ('APAC', 'Melbourne'),
#  ('APAC', 'Middle East'),
#  ('APAC', 'Montreal'),
#  ('APAC', 'Mumbai'),
#  ('APAC', 'Netherlands'),
#  ('APAC', 'Osaka'),
#  ('APAC', 'Salt Lake City'),
#  ('APAC', 'Sao Paulo'),
#  ('APAC', 'Seoul'),
#  ('APAC', 'Singapore'),
#  ('APAC', 'South America'),
#  ('APAC', 'Sydney'),
#  ('APAC', 'Toronto'),
#  ('APAC', 'Virginia'),
#  ('APAC', 'Warsaw'),
#  ('APAC', 'Western Europe'),
#  ('APAC', 'Zurich'),
#  ('Americas', 'APAC'),
#  ('Americas', 'Africa'),
#  ('Americas', 'Americas'),
#  ('Americas', 'Australia'),
#  ('Americas', 'Central America'),
#  ('Americas', 'China'),
#  ('Americas', 'Delhi'),
#  ('Americas', 'EMEA'),
#  ('Americas', 'Eastern Europe'),
#  ('Americas', 'Finland'),
#  ('Americas', 'Frankfurt'),
#  ('Americas', 'Hong Kong'),
#  ('Americas', 'India'),
#  ('Americas', 'Jakarta'),
#  ('Americas', 'Japan'),
#  ('Americas', 'Las Vegas'),
#  ('Americas', 'London'),
#  ('Americas', 'Los Angeles'),
#  ('Americas', 'Melbourne'),
#  ('Americas', 'Middle East'),
#  ('Americas', 'Montreal'),
#  ('Americas', 'Mumbai'),
#  ('Americas', 'Netherlands'),
#  ('Americas', 'Osaka'),
#  ('Americas', 'Salt Lake City'),
#  ('Americas', 'Sao Paulo'),
#  ('Americas', 'Seoul'),
#  ('Americas', 'Singapore'),
#  ('Americas', 'South America'),
#  ('Americas', 'Sydney'),
#  ('Americas', 'Toronto'),
#  ('Americas', 'Virginia'),
#  ('Americas', 'Warsaw'),
#  ('Americas', 'Western Europe'),
#  ('Americas', 'Zurich'),
#  ('Delhi', 'APAC'),
#  ('Delhi', 'Africa'),
#  ('Delhi', 'Americas'),
#  ('Delhi', 'Australia'),
#  ('Delhi', 'Central America'),
#  ('Delhi', 'China'),
#  ('Delhi', 'EMEA'),
#  ('Delhi', 'Eastern Europe'),
#  ('Delhi', 'India'),
#  ('Delhi', 'Japan'),
#  ('Delhi', 'Middle East'),
#  ('Delhi', 'South America'),
#  ('Delhi', 'Western Europe'),
#  ('EMEA', 'APAC'),
#  ('EMEA', 'Africa'),
#  ('EMEA', 'Americas'),
#  ('EMEA', 'Australia'),
#  ('EMEA', 'Central America'),
#  ('EMEA', 'China'),
#  ('EMEA', 'Delhi'),
#  ('EMEA', 'EMEA'),
#  ('EMEA', 'Eastern Europe'),
#  ('EMEA', 'Finland'),
#  ('EMEA', 'Frankfurt'),
#  ('EMEA', 'Hong Kong'),
#  ('EMEA', 'India'),
#  ('EMEA', 'Jakarta'),
#  ('EMEA', 'Japan'),
#  ('EMEA', 'Las Vegas'),
#  ('EMEA', 'London'),
#  ('EMEA', 'Los Angeles'),
#  ('EMEA', 'Melbourne'),
#  ('EMEA', 'Middle East'),
#  ('EMEA', 'Montreal'),
#  ('EMEA', 'Mumbai'),
#  ('EMEA', 'Netherlands'),
#  ('EMEA', 'Osaka'),
#  ('EMEA', 'Salt Lake City'),
#  ('EMEA', 'Sao Paulo'),
#  ('EMEA', 'Seoul'),
#  ('EMEA', 'Singapore'),
#  ('EMEA', 'South America'),
#  ('EMEA', 'Sydney'),
#  ('EMEA', 'Toronto'),
#  ('EMEA', 'Virginia'),
#  ('EMEA', 'Warsaw'),
#  ('EMEA', 'Western Europe'),
#  ('EMEA', 'Zurich'),
#  ('Finland', 'APAC'),
#  ('Finland', 'Africa'),
#  ('Finland', 'Americas'),
#  ('Finland', 'Australia'),
#  ('Finland', 'Central America'),
#  ('Finland', 'China'),
#  ('Finland', 'EMEA'),
#  ('Finland', 'Eastern Europe'),
#  ('Finland', 'India'),
#  ('Finland', 'Japan'),
#  ('Finland', 'Middle East'),
#  ('Finland', 'South America'),
#  ('Finland', 'Western Europe'),
#  ('Frankfurt', 'APAC'),
#  ('Frankfurt', 'Africa'),
#  ('Frankfurt', 'Americas'),
#  ('Frankfurt', 'Australia'),
#  ('Frankfurt', 'Central America'),
#  ('Frankfurt', 'China'),
#  ('Frankfurt', 'EMEA'),
#  ('Frankfurt', 'Eastern Europe'),
#  ('Frankfurt', 'India'),
#  ('Frankfurt', 'Japan'),
#  ('Frankfurt', 'Middle East'),
#  ('Frankfurt', 'South America'),
#  ('Frankfurt', 'Western Europe'),
#  ('Hong Kong', 'APAC'),
#  ('Hong Kong', 'Africa'),
#  ('Hong Kong', 'Americas'),
#  ('Hong Kong', 'Australia'),
#  ('Hong Kong', 'Central America'),
#  ('Hong Kong', 'China'),
#  ('Hong Kong', 'EMEA'),
#  ('Hong Kong', 'Eastern Europe'),
#  ('Hong Kong', 'India'),
#  ('Hong Kong', 'Japan'),
#  ('Hong Kong', 'Middle East'),
#  ('Hong Kong', 'South America'),
#  ('Hong Kong', 'Western Europe'),
#  ('Jakarta', 'APAC'),
#  ('Jakarta', 'Africa'),
#  ('Jakarta', 'Americas'),
#  ('Jakarta', 'Australia'),
#  ('Jakarta', 'Central America'),
#  ('Jakarta', 'China'),
#  ('Jakarta', 'EMEA'),
#  ('Jakarta', 'Eastern Europe'),
#  ('Jakarta', 'India'),
#  ('Jakarta', 'Japan'),
#  ('Jakarta', 'Middle East'),
#  ('Jakarta', 'South America'),
#  ('Jakarta', 'Western Europe'),
#  ('Japan', 'APAC'),
#  ('Japan', 'Africa'),
#  ('Japan', 'Americas'),
#  ('Japan', 'Australia'),
#  ('Japan', 'Central America'),
#  ('Japan', 'China'),
#  ('Japan', 'Delhi'),
#  ('Japan', 'EMEA'),
#  ('Japan', 'Eastern Europe'),
#  ('Japan', 'Finland'),
#  ('Japan', 'Frankfurt'),
#  ('Japan', 'Hong Kong'),
#  ('Japan', 'India'),
#  ('Japan', 'Jakarta'),
#  ('Japan', 'Japan'),
#  ('Japan', 'Las Vegas'),
#  ('Japan', 'London'),
#  ('Japan', 'Los Angeles'),
#  ('Japan', 'Melbourne'),
#  ('Japan', 'Middle East'),
#  ('Japan', 'Montreal'),
#  ('Japan', 'Mumbai'),
#  ('Japan', 'Netherlands'),
#  ('Japan', 'Osaka'),
#  ('Japan', 'Salt Lake City'),
#  ('Japan', 'Sao Paulo'),
#  ('Japan', 'Seoul'),
#  ('Japan', 'Singapore'),
#  ('Japan', 'South America'),
#  ('Japan', 'Sydney'),
#  ('Japan', 'Toronto'),
#  ('Japan', 'Virginia'),
#  ('Japan', 'Warsaw'),
#  ('Japan', 'Western Europe'),
#  ('Japan', 'Zurich'),
#  ('Las Vegas', 'APAC'),
#  ('Las Vegas', 'Africa'),
#  ('Las Vegas', 'Americas'),
#  ('Las Vegas', 'Australia'),
#  ('Las Vegas', 'Central America'),
#  ('Las Vegas', 'China'),
#  ('Las Vegas', 'EMEA'),
#  ('Las Vegas', 'Eastern Europe'),
#  ('Las Vegas', 'India'),
#  ('Las Vegas', 'Japan'),
#  ('Las Vegas', 'Middle East'),
#  ('Las Vegas', 'South America'),
#  ('Las Vegas', 'Western Europe'),
#  ('London', 'APAC'),
#  ('London', 'Africa'),
#  ('London', 'Americas'),
#  ('London', 'Australia'),
#  ('London', 'Central America'),
#  ('London', 'China'),
#  ('London', 'EMEA'),
#  ('London', 'Eastern Europe'),
#  ('London', 'India'),
#  ('London', 'Japan'),
#  ('London', 'Middle East'),
#  ('London', 'South America'),
#  ('London', 'Western Europe'),
#  ('Los Angeles', 'APAC'),
#  ('Los Angeles', 'Africa'),
#  ('Los Angeles', 'Americas'),
#  ('Los Angeles', 'Australia'),
#  ('Los Angeles', 'Central America'),
#  ('Los Angeles', 'China'),
#  ('Los Angeles', 'EMEA'),
#  ('Los Angeles', 'Eastern Europe'),
#  ('Los Angeles', 'India'),
#  ('Los Angeles', 'Japan'),
#  ('Los Angeles', 'Middle East'),
#  ('Los Angeles', 'South America'),
#  ('Los Angeles', 'Western Europe'),
#  ('Melbourne', 'APAC'),
#  ('Melbourne', 'Africa'),
#  ('Melbourne', 'Americas'),
#  ('Melbourne', 'Australia'),
#  ('Melbourne', 'Central America'),
#  ('Melbourne', 'China'),
#  ('Melbourne', 'EMEA'),
#  ('Melbourne', 'Eastern Europe'),
#  ('Melbourne', 'India'),
#  ('Melbourne', 'Japan'),
#  ('Melbourne', 'Middle East'),
#  ('Melbourne', 'South America'),
#  ('Melbourne', 'Western Europe'),
#  ('Montreal', 'APAC'),
#  ('Montreal', 'Africa'),
#  ('Montreal', 'Americas'),
#  ('Montreal', 'Australia'),
#  ('Montreal', 'Central America'),
#  ('Montreal', 'China'),
#  ('Montreal', 'EMEA'),
#  ('Montreal', 'Eastern Europe'),
#  ('Montreal', 'India'),
#  ('Montreal', 'Japan'),
#  ('Montreal', 'Middle East'),
#  ('Montreal', 'South America'),
#  ('Montreal', 'Western Europe'),
#  ('Mumbai', 'APAC'),
#  ('Mumbai', 'Africa'),
#  ('Mumbai', 'Americas'),
#  ('Mumbai', 'Australia'),
#  ('Mumbai', 'Central America'),
#  ('Mumbai', 'China'),
#  ('Mumbai', 'EMEA'),
#  ('Mumbai', 'Eastern Europe'),
#  ('Mumbai', 'India'),
#  ('Mumbai', 'Japan'),
#  ('Mumbai', 'Middle East'),
#  ('Mumbai', 'South America'),
#  ('Mumbai', 'Western Europe'),
#  ('Netherlands', 'APAC'),
#  ('Netherlands', 'Africa'),
#  ('Netherlands', 'Americas'),
#  ('Netherlands', 'Australia'),
#  ('Netherlands', 'Central America'),
#  ('Netherlands', 'China'),
#  ('Netherlands', 'EMEA'),
#  ('Netherlands', 'Eastern Europe'),
#  ('Netherlands', 'India'),
#  ('Netherlands', 'Japan'),
#  ('Netherlands', 'Middle East'),
#  ('Netherlands', 'South America'),
#  ('Netherlands', 'Western Europe'),
#  ('Northern Virginia', 'internet'),
#  ('Osaka', 'APAC'),
#  ('Osaka', 'Africa'),
#  ('Osaka', 'Americas'),
#  ('Osaka', 'Australia'),
#  ('Osaka', 'Central America'),
#  ('Osaka', 'China'),
#  ('Osaka', 'EMEA'),
#  ('Osaka', 'Eastern Europe'),
#  ('Osaka', 'India'),
#  ('Osaka', 'Japan'),
#  ('Osaka', 'Middle East'),
#  ('Osaka', 'South America'),
#  ('Osaka', 'Western Europe'),
#  ('Salt Lake City', 'APAC'),
#  ('Salt Lake City', 'Africa'),
#  ('Salt Lake City', 'Americas'),
#  ('Salt Lake City', 'Australia'),
#  ('Salt Lake City', 'Central America'),
#  ('Salt Lake City', 'China'),
#  ('Salt Lake City', 'EMEA'),
#  ('Salt Lake City', 'Eastern Europe'),
#  ('Salt Lake City', 'India'),
#  ('Salt Lake City', 'Japan'),
#  ('Salt Lake City', 'Middle East'),
#  ('Salt Lake City', 'South America'),
#  ('Salt Lake City', 'Western Europe'),
#  ('Sao Paulo', 'APAC'),
#  ('Sao Paulo', 'Africa'),
#  ('Sao Paulo', 'Americas'),
#  ('Sao Paulo', 'Australia'),
#  ('Sao Paulo', 'Central America'),
#  ('Sao Paulo', 'China'),
#  ('Sao Paulo', 'EMEA'),
#  ('Sao Paulo', 'Eastern Europe'),
#  ('Sao Paulo', 'India'),
#  ('Sao Paulo', 'Japan'),
#  ('Sao Paulo', 'Middle East'),
#  ('Sao Paulo', 'South America'),
#  ('Sao Paulo', 'Western Europe'),
#  ('Seoul', 'APAC'),
#  ('Seoul', 'Africa'),
#  ('Seoul', 'Americas'),
#  ('Seoul', 'Australia'),
#  ('Seoul', 'Central America'),
#  ('Seoul', 'China'),
#  ('Seoul', 'EMEA'),
#  ('Seoul', 'Eastern Europe'),
#  ('Seoul', 'India'),
#  ('Seoul', 'Japan'),
#  ('Seoul', 'Middle East'),
#  ('Seoul', 'South America'),
#  ('Seoul', 'Western Europe'),
#  ('Singapore', 'APAC'),
#  ('Singapore', 'Africa'),
#  ('Singapore', 'Americas'),
#  ('Singapore', 'Australia'),
#  ('Singapore', 'Central America'),
#  ('Singapore', 'China'),
#  ('Singapore', 'EMEA'),
#  ('Singapore', 'Eastern Europe'),
#  ('Singapore', 'India'),
#  ('Singapore', 'Japan'),
#  ('Singapore', 'Middle East'),
#  ('Singapore', 'South America'),
#  ('Singapore', 'Western Europe'),
#  ('Sydney', 'APAC'),
#  ('Sydney', 'Africa'),
#  ('Sydney', 'Americas'),
#  ('Sydney', 'Australia'),
#  ('Sydney', 'Central America'),
#  ('Sydney', 'China'),
#  ('Sydney', 'EMEA'),
#  ('Sydney', 'Eastern Europe'),
#  ('Sydney', 'India'),
#  ('Sydney', 'Japan'),
#  ('Sydney', 'Middle East'),
#  ('Sydney', 'South America'),
#  ('Sydney', 'Western Europe'),
#  ('Toronto', 'APAC'),
#  ('Toronto', 'Africa'),
#  ('Toronto', 'Americas'),
#  ('Toronto', 'Australia'),
#  ('Toronto', 'Central America'),
#  ('Toronto', 'China'),
#  ('Toronto', 'EMEA'),
#  ('Toronto', 'Eastern Europe'),
#  ('Toronto', 'India'),
#  ('Toronto', 'Japan'),
#  ('Toronto', 'Middle East'),
#  ('Toronto', 'South America'),
#  ('Toronto', 'Western Europe'),
#  ('Virginia', 'APAC'),
#  ('Virginia', 'Africa'),
#  ('Virginia', 'Americas'),
#  ('Virginia', 'Australia'),
#  ('Virginia', 'Central America'),
#  ('Virginia', 'China'),
#  ('Virginia', 'EMEA'),
#  ('Virginia', 'Eastern Europe'),
#  ('Virginia', 'India'),
#  ('Virginia', 'Japan'),
#  ('Virginia', 'Middle East'),
#  ('Virginia', 'South America'),
#  ('Virginia', 'Western Europe'),
#  ('Warsaw', 'APAC'),
#  ('Warsaw', 'Africa'),
#  ('Warsaw', 'Americas'),
#  ('Warsaw', 'Australia'),
#  ('Warsaw', 'Central America'),
#  ('Warsaw', 'China'),
#  ('Warsaw', 'EMEA'),
#  ('Warsaw', 'Eastern Europe'),
#  ('Warsaw', 'India'),
#  ('Warsaw', 'Japan'),
#  ('Warsaw', 'Middle East'),
#  ('Warsaw', 'South America'),
#  ('Warsaw', 'Western Europe'),
#  ('Zurich', 'APAC'),
#  ('Zurich', 'Africa'),
#  ('Zurich', 'Americas'),
#  ('Zurich', 'Australia'),
#  ('Zurich', 'Central America'),
#  ('Zurich', 'China'),
#  ('Zurich', 'EMEA'),
#  ('Zurich', 'Eastern Europe'),
#  ('Zurich', 'India'),
#  ('Zurich', 'Japan'),
#  ('Zurich', 'Middle East'),
#  ('Zurich', 'South America'),
#  ('Zurich', 'Western Europe')}
